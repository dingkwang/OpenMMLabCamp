# %% [markdown]
# # 耳朵脉位检测
#
# Dingkang

# %% [markdown]
# ## 进入mmdetection主目录

# %%
import os
# os.chdir('mmdetection')
os.chdir('/home/dkwang/learn_mmlab/mmdetection')

# %% [markdown]
# ## 目标检测算法：RTMDet

# %%
# 建议在命令行中运行
# !python tools/train.py data/MMPose_hw1/rtmdet_tiny_ear.py

# %% [markdown]
# ## PTMDetection 评估精度

# %%
! python tools/test.py data/MMPose_hw1/rtmdet_tiny_ear.py \
                      work_dirs/rtmdet_tiny_ear/best_coco_bbox_mAP_epoch_175.pth
# Out:
# 06/04 16:19:03 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.10 (default, Mar 13 2023, 10:26:41) [GCC 9.4.0]
#     CUDA available: True
#     numpy_random_seed: 538500989
#     GPU 0,1: NVIDIA GeForce RTX 4090
#     CUDA_HOME: /usr/local/cuda-11.4
#     NVCC: Cuda compilation tools, release 11.4, V11.4.152
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
#     PyTorch: 1.12.1+cu113
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.6.0 (Git Hash 52b5f107dd9cf10910aaa19cb47f3abf9b349815)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.3
# ...

# %% [markdown]
# ## RTMDet 训练过程可视化

# %%
import os
os.chdir('/home/dkwang/learn_mmlab/mmdetection')

import pandas as pd
from tqdm import tqdm

import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['axes.unicode_minus']=False  # 用来正常显示负号

# 日志文件路径
log_path = 'work_dirs/rtmdet_tiny_ear/20230604_111732/20230604_111732.log'

# %% [markdown]
# ## RTMPose 测试集上评估模型精度

# %%
# !python tools/test.py data/MMPose_hw1/rtmpose-s-ear.py \
                      work_dirs/rtmpose-s-ear/best_PCK_epoch_210.pth
# Out:
# 06/04 15:22:02 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.10 (default, Mar 13 2023, 10:26:41) [GCC 9.4.0]
#     CUDA available: True
#     numpy_random_seed: 21
#     GPU 0,1: NVIDIA GeForce RTX 4090
#     CUDA_HOME: /usr/local/cuda-11.4
#     NVCC: Cuda compilation tools, release 11.4, V11.4.152
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
#     PyTorch: 1.12.1+cu113
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.6.0 (Git Hash 52b5f107dd9cf10910aaa19cb47f3abf9b349815)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.3
# ...

# %% [markdown]
# ## 用自己的耳朵验证

# %%
# !python demo/image_demo.py \
        /home/dkwang/learn_mmlab/OpenMMLabCamp/projects/hw_1_mmpose/my_ear.png \
        data/MMPose_hw1/rtmdet_tiny_ear.py \
        --weights work_dirs/rtmdet_tiny_ear/best_coco_bbox_mAP_epoch_175.pth \
        --out-dir outputs/ear_rtmdet \
        --device cuda:0 \
        --pred-score-thr 0.3
# Out:
# Loads checkpoint by local backend from path: work_dirs/rtmdet_tiny_ear/best_coco_bbox_mAP_epoch_175.pth
# 06/04 16:38:40 - mmengine - WARNING - Failed to search registry with scope "mmdet" in the "function" registry tree. As a workaround, the current "function" registry in "mmengine" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmdet" is a correct scope, or whether the registry is initialized.
# 06/04 16:38:40 - mmengine - WARNING - `Visualizer` backend is not initialized because save_dir is None.
# Inference ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Traceback (most recent call last):
#   File "demo/image_demo.py", line 113, in <module>
#     main()
#   File "demo/image_demo.py", line 105, in main
#     inferencer(**call_args)
#   File "/home/dkwang/learn_mmlab/mmdetection/mmdet/apis/det_inferencer.py", line 342, in __call__
#     for ori_inputs, data in track(inputs, description='Inference'):
# ...

# %% [markdown]
# ## RTMPose Training

# %%
import os
os.chdir('/home/dkwang/learn_mmlab/mmpose')

# %%
# 建议在命令行中运行
# !python tools/train.py data/MMPose_hw1/rtmpose-s-ear.py

# %%
# RTMDet --> RTMPose
# !python demo/topdown_demo_with_mmdet.py \
        data/MMPose_hw1/rtmdet_tiny_ear.py \
        data/MMPose_hw1/best_coco_bbox_mAP_epoch_175.pth \
        data/MMPose_hw1/rtmpose-s-ear.py \
        work_dirs/rtmpose-s-ear/best_PCK_epoch_270.pth \
        --input /home/dkwang/learn_mmlab/OpenMMLabCamp/projects/hw_1_mmpose/my_ear.png \
        --output-root outputs/rtm_ear \
        --device cuda:0 \
        --bbox-thr 0.5 \
        --kpt-thr 0.5 \
        --nms-thr 0.3 \
        --radius 16 \
        --thickness 10 \
        --draw-bbox \
        --draw-heatmap \
        --show-kpt-idx
# Out:
# Loads checkpoint by local backend from path: data/MMPose_hw1/best_coco_bbox_mAP_epoch_175.pth
# Loads checkpoint by local backend from path: work_dirs/rtmpose-s-ear/best_PCK_epoch_270.pth
# 06/04 16:44:13 - mmengine - WARNING - `Visualizer` backend is not initialized because save_dir is None.
# /home/dkwang/learn_mmlab/environment/mmcv2/lib/python3.8/site-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# /home/dkwang/learn_mmlab/mmpose/mmpose/models/heads/coord_cls_heads/rtmcc_head.py:217: UserWarning: The predicted simcc values are normalized for visualization. This may cause discrepancy between the keypoint scores and the 1D heatmaps.
#   warnings.warn('The predicted simcc values are normalized for '
